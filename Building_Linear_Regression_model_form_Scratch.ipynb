# %% [markdown]
# <a href="https://colab.research.google.com/github/vikkrock/Maths-for-ML-DL/blob/main/Building_Linear_Regression_model_form_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Linear Regression:**
#
# **Y = wX + b**
#
# *Y --> Dependent Variable*
# *X --> Independent Variable*
# *w --> weight*
# *b --> bias*

# %% [markdown]
# #### **Gradient Descent:**
#
# Gradient Descent is an optimization algorithm used for minimizing the loss function in various machine learning algorithms. It is used for updating the parameters of the learning model.
#
# **w = w - α*dw**
#
# **b = b - α*db**
#
# a= Learning rate
#
# #### **Learning Rate:**
#
# Learning rate is a tuning parameter in an optimization algorithm that determines the step size at each iteration while moving toward a minimum of a loss function.
#
#
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In Class Linear Regression we define 4 **function**:
# 1. __init__() ->  initiating the parameters (learning rate & no. of iterations)
#
# 2. fit()-> used to train linear regression model with the dataset
#
# 3. update_weights()-> used to update parameter (weight & bias)
#
# 4. predict()-> to get prediction
#
#
# **Parameters**
# 1. __init__(self, learn_rt, iter)
# 2. fit(self, )
# 3. update_weights()
# 4. predict()
#
# **self**=> when we call our model as (model= Linear_Regression())using a instance called model. So, when we use self it will call model, which we made.

# %%
class Linear_Regression():

  def __init__(self,learn_rt,iter):

    self.learn_rt = learn_rt
    self.iter = iter
  def fit(self,X,Y):
    # number of training examples & number of features
    self.m,self.n=X.shape #m=no. of rows      n=no. of columns

    # initiating weight and bias
    self.w = np.zeros(self.n) # we are creating matrix with n no. of column and all contain 0. wt. initiate with matrix
    self.b = 0 # bias initiated with a value which is 0
    self.X = X
    self.Y = Y  # X and Y are dataset which we get

    #implementing Gradient descent
    for i in range(self.iter):
      self.update_weights()

  def update_weights(self):
    Y_predict = self.predict(self.X)

    # calculate gradients
    dw= -(2* (self.X.T).dot(self.Y -Y_predict))/self.m
    db= -(2* np.sum(self.Y - Y_prediction))/self.m

    #updating weights
    self.w -=self.learn_rt*dw
    self.b -=self.learn_rt*db

# line function for direction
  def predict(self, X):
    return X.dot(self.w)+self.b

# %% [markdown]
# initiate as
# Y=0(X)+0

# %% [markdown]
# ### Workflow of Linear Regression Model
# **step-1** : Set learning rate and no. of iteration : Initiate Random weight and bias.
#
# **step-2** : Build Linear Regression Equation (**y= wx+b**)
#
# **step-3** : Find the y pred value for given x value for Corresponding weight and bias.
#
# **step-4** : Check the loss function for these parameter i.e. diifference between 'y_pred' and actual y.
#
# **step-5** : Update parameter using Gradient descent (new weight and bias)
#
# **step-6** :step 3, 4, 5 repated till we get minimum loss function
#
# Finally we get our best model with min loss function.
